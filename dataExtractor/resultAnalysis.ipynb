# %%
import os
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure plots render with a clean style
sns.set(style="whitegrid")

# ----------------------------
# Configuration:
# List your CSV files here, and map each to its sentiment column
# ----------------------------
datasets = {
    "combined_baseline_nb_textblob.csv": "Sentiment",
    "combined_baseline_nb_vader.csv": "Sentiment",
    "combined_sentiment_nb_textblob.csv": "Sentiment",
    "combined_sentiment_nb_vader.csv": "Sentiment",
    "combined_textblob.csv": "predicted_label",
    "combined_vader.csv": "predicted_label",
    "dataset_chatgpt_sentiment.csv": "Sentiment",
    "bert_predictions_all(TextBlob).csv": "BERT_Predicted_Sentiment",
    "bert_predictions_all(VADER).csv": "BERT_Predicted_Sentiment",
    "bert_predictions_all(ChatGpt).csv": "BERT_Predicted_Sentiment"
}

# Mapping from filenames to display names
display_names = {
    "combined_baseline_nb_textblob.csv": "TB - NB (Baseline)",
    "combined_baseline_nb_vader.csv": "V - NB (Baseline)",
    "combined_sentiment_nb_textblob.csv": "TB - NB (GridSearchCV)",
    "combined_sentiment_nb_vader.csv": "V - NB (GridSearchCV)",
    "combined_textblob.csv": "TextBlob (Labelled)",
    "combined_vader.csv": "VADER (Labelled)",
    "dataset_chatgpt_sentiment.csv": "ChatGPT (Labelled)",
    "bert_predictions_all(TextBlob).csv": "BERT - TB (Labelled)",
    "bert_predictions_all(VADER).csv": "BERT - V (Labelled)",
    "bert_predictions_all(ChatGpt).csv": "BERT - CGPT (Labelled)"
}
# ----------------------------
# Helper Functions
# ----------------------------

def load_and_prepare(df_path, sentiment_col):
    """
    1. Load CSV from df_path
    2. Parse 'Mentioned_Parties' (string-encoded list) into actual Python lists.
    3. Explode each row so that each (party, sentiment) pair is its own row.
    4. Normalize 'Sentiment' values to exactly 'Positive', 'Neutral', or 'Negative'.
    Returns a DataFrame with columns ['Party', 'Sentiment'].
    """
    df = pd.read_csv(df_path)

    # Parse Mentioned_Parties from string to list
    df["Mentioned_Parties"] = df["Mentioned_Parties"].apply(ast.literal_eval)

    # Explode parties
    exploded = df.explode("Mentioned_Parties").rename(columns={"Mentioned_Parties": "Party"})

    # Keep only needed columns
    exploded = exploded[["Party", sentiment_col]].copy()
    exploded = exploded.rename(columns={sentiment_col: "Sentiment"})

    # Normalize sentiment: strip whitespace, lowercase, then capitalize
    exploded["Sentiment"] = (
        exploded["Sentiment"]
        .astype(str)
        .str.strip()
        .str.lower()
        .map({
            "positive": "Positive",
            "neutral": "Neutral",
            "negative": "Negative"
        })
    )

    # Drop any rows where normalization failed (i.e., got NaN)
    exploded = exploded.dropna(subset=["Sentiment"])

    # Drop rows where Party is empty or 'OTHER'
    exploded = exploded[
        (exploded["Party"].astype(str).str.strip() != "") &
        (exploded["Party"] != "OTHER")
        ]

    return exploded


def party_sentiment_counts(df_exploded):
    """
    Given an exploded DataFrame with columns ['Party', 'Sentiment'],
    returns a pivot dataframe: index=Party, columns=[Positive, Neutral, Negative], values=count
    """
    pivot = (
        df_exploded
        .groupby(["Party", "Sentiment"])
        .size()
        .unstack(fill_value=0)[["Positive", "Neutral", "Negative"]]
        .sort_index()
    )
    return pivot


def plot_stacked_bar(pivot_df, title=None, display_name=None):
    """
    Modified to use display_name instead of filename in title
    """
    ax = pivot_df.plot(
        kind="bar",
        stacked=True,
        figsize=(12, 6),
        colormap="coolwarm"
    )
    ax.set_xlabel("Party")
    ax.set_ylabel("Number of Comments")
    if display_name:
        ax.set_title(f"Sentiment Distribution by Party\n({display_name})")
    elif title:
        ax.set_title(title)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()


def plot_pie_charts(pivot_df, top_n=5, display_name=""):
    """
    Modified to use display_name in pie chart titles
    """
    totals = pivot_df.sum(axis=1).sort_values(ascending=False)
    top_parties = totals.head(top_n).index.tolist()
    for party in top_parties:
        counts = pivot_df.loc[party]
        plt.figure(figsize=(4, 4))
        counts.plot.pie(
            labels=[f"{sent} ({counts[sent]})" for sent in counts.index],
            autopct="%1.1f%%",
            startangle=140,
            colors=["#2ca02c", "#1f77b4", "#d62728"]
        )
        plt.title(f"{party} Sentiment Breakdown\n{display_name}")
        plt.ylabel("")  # Hide default y-label
        plt.tight_layout()
        plt.show()

def most_frequent_parties(df_exploded, top_n=10):
    """
    Returns a Series of top_n parties by mention count.
    """
    counts = df_exploded["Party"].value_counts()
    return counts.head(top_n)


def plot_top_parties(counts_series, display_name=None):
    """
    Modified to use display_name in title
    """
    plt.figure(figsize=(10, 5))
    sns.barplot(
        x=counts_series.values,
        y=counts_series.index,
        palette="viridis"
    )
    plt.xlabel("Number of Mentions")
    plt.ylabel("Party")
    if display_name:
        plt.title(f"Top 10 Mentioned Parties\n({display_name})")
    plt.tight_layout()
    plt.show()

def sentiment_ratio(pivot_df, min_count=10):
    """
    Given a pivot_df with columns ['Positive','Neutral','Negative'] per party, compute ratio:
    ratio = Positive / (Positive+Negative). Returns a DataFrame with additional columns:
      - 'Total'
      - 'Positive_Count','Neutral_Count','Negative_Count'
      - 'Positive_Ratio'  (Positive / Total)
      - 'Negative_Ratio'  (Negative / Total)
      - 'Neutral_Ratio'   (Neutral / Total)
      - 'Pos_vs_Neg_Ratio' (Positive / Negative)  (handle division by zero)
    Only includes parties with total counts >= min_count (default=10)
    """
    df = pivot_df.copy()
    df["Total"] = df.sum(axis=1)
    
    # Filter out parties with low counts
    df = df[df["Total"] >= min_count].copy()
    
    if len(df) == 0:
        print(f"\nWarning: No parties meet the minimum count threshold of {min_count}")
        return pd.DataFrame()  # Return empty dataframe if no parties meet threshold
    
    df["Positive_Count"] = df["Positive"]
    df["Neutral_Count"] = df["Neutral"]
    df["Negative_Count"] = df["Negative"]
    df["Positive_Ratio"] = df["Positive"] / df["Total"]
    df["Neutral_Ratio"] = df["Neutral"] / df["Total"]
    df["Negative_Ratio"] = df["Negative"] / df["Total"]
    df["Pos_vs_Neg_Ratio"] = df.apply(
        lambda row: row["Positive"] / row["Negative"] if row["Negative"] > 0 else float("inf"),
        axis=1
    )
    return df.sort_values("Positive_Ratio", ascending=False)

# ----------------------------
# Updated Main Analysis Loop
# ----------------------------
for filename, sentiment_col in datasets.items():
    if not os.path.exists(filename):
        print(f"File '{filename}' not found. Skipping.")
        continue

    display_name = display_names.get(filename, filename)  # Get the pretty name or fallback to filename
    
    print(f"\n--- Analyzing {filename} (sentiment column: '{sentiment_col}') ---")
    exploded_df = load_and_prepare(filename, sentiment_col)

    # 1. Party-wise Sentiment Distribution
    pivot = party_sentiment_counts(exploded_df)
    print("\nParty-wise sentiment counts:\n", pivot)

    # Plot stacked bar chart with display name
    plot_stacked_bar(pivot, display_name=display_name)

    # Plot pie charts with display name
    plot_pie_charts(pivot, top_n=5, display_name=display_name)

    # 2. Most Frequently Mentioned Party
    top_parties = most_frequent_parties(exploded_df, top_n=10)
    print("\nTop 10 most frequently mentioned parties:\n", top_parties)
    plot_top_parties(top_parties, display_name=display_name)

    # 3. Party Comparison by Sentiment Ratio (with minimum count threshold)
    ratio_df = sentiment_ratio(pivot, min_count=10)
    
    if not ratio_df.empty:
        print("\nParty sentiment ratios (only parties with ≥10 total mentions):\n", ratio_df[[
            "Positive_Count", "Neutral_Count", "Negative_Count",
            "Positive_Ratio", "Neutral_Ratio", "Negative_Ratio", "Pos_vs_Neg_Ratio"
        ]])

        # Identify most favorable (highest Positive_Ratio) and most critical (lowest Positive_Ratio)
        most_favorable = ratio_df.head(1)
        most_critical = ratio_df.tail(1)
        print("\nMost Favorable Party (≥10 mentions):\n", most_favorable[["Positive_Ratio"]])
        print("Most Critical Party (≥10 mentions):\n", most_critical[["Positive_Ratio"]])

        # Barplot of Positive_Ratio with display name
        plt.figure(figsize=(12, 6))
        sns.barplot(
            x=ratio_df["Positive_Ratio"],
            y=ratio_df.index,
            palette="summer"
        )
        plt.xlabel("Positive Ratio (Positive / Total)")
        plt.ylabel("Party")
        plt.title(f"Positive Ratio by Party (≥10 mentions)\n({display_name})")
        plt.tight_layout()
        plt.show()
    else:
        print("\nNo parties have sufficient mentions (≥10) for ratio analysis")
# Out:
# --- Analyzing combined_baseline_nb_textblob.csv (sentiment column: 'Sentiment') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              315      321        77
# DAP              46       59        39
# GPS               5        7         0
# GRS               5        4         0
# GTA              61       92        26
# PAS              25       20        13
# PH              137      147        38
# PKR              22       28         7
# PN              140      129        22
# UMNO            280      256        61
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      58
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PN                    140            129              22        0.481100
# UMNO                  280            256              61        0.469012
# BN                    315            321              77        0.441795
# PAS                    25             20              13        0.431034
# PH                    137            147              38        0.425466
# GPS                     5              7               0        0.416667
# PKR                    22             28               7        0.385965
# GTA                    61             92              26        0.340782
# DAP                    46             59              39        0.319444
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PN              0.443299        0.075601          6.363636
# UMNO            0.428811        0.102178          4.590164
# BN              0.450210        0.107994          4.090909
# PAS             0.344828        0.224138          1.923077
# PH              0.456522        0.118012          3.605263
# GPS             0.583333        0.000000               inf
# PKR             0.491228        0.122807          3.142857
# GTA             0.513966        0.145251          2.346154
# DAP             0.409722        0.270833          1.179487
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PN                 0.4811
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# DAP              0.319444
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing combined_baseline_nb_vader.csv (sentiment column: 'Sentiment') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              382      177       154
# DAP              55       47        42
# GPS               4        6         2
# GRS               1        6         2
# GTA              67       67        45
# PAS              31       16        11
# PH              166       90        66
# PKR              36       13         8
# PN              158       95        38
# UMNO            305      142       150
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      58
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PKR                    36             13               8        0.631579
# PN                    158             95              38        0.542955
# BN                    382            177             154        0.535764
# PAS                    31             16              11        0.534483
# PH                    166             90              66        0.515528
# UMNO                  305            142             150        0.510888
# DAP                    55             47              42        0.381944
# GTA                    67             67              45        0.374302
# GPS                     4              6               2        0.333333
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PKR             0.228070        0.140351          4.500000
# PN              0.326460        0.130584          4.157895
# BN              0.248247        0.215989          2.480519
# PAS             0.275862        0.189655          2.818182
# PH              0.279503        0.204969          2.515152
# UMNO            0.237856        0.251256          2.033333
# DAP             0.326389        0.291667          1.309524
# GTA             0.374302        0.251397          1.488889
# GPS             0.500000        0.166667          2.000000
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PKR              0.631579
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# GPS              0.333333
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing combined_sentiment_nb_textblob.csv (sentiment column: 'Sentiment') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              278      389        46
# DAP              36       87        21
# GPS               5        7         0
# GRS               5        4         0
# GTA              49      110        20
# PAS              23       34         2
# PH              128      169        25
# PKR              18       36         3
# PN              132      147        12
# UMNO            255      308        34
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      59
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PN                    132            147              12        0.453608
# UMNO                  255            308              34        0.427136
# GPS                     5              7               0        0.416667
# PH                    128            169              25        0.397516
# BN                    278            389              46        0.389902
# PAS                    23             34               2        0.389831
# PKR                    18             36               3        0.315789
# GTA                    49            110              20        0.273743
# DAP                    36             87              21        0.250000
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PN              0.505155        0.041237         11.000000
# UMNO            0.515913        0.056951          7.500000
# GPS             0.583333        0.000000               inf
# PH              0.524845        0.077640          5.120000
# BN              0.545582        0.064516          6.043478
# PAS             0.576271        0.033898         11.500000
# PKR             0.631579        0.052632          6.000000
# GTA             0.614525        0.111732          2.450000
# DAP             0.604167        0.145833          1.714286
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PN               0.453608
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# DAP                  0.25
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing combined_sentiment_nb_vader.csv (sentiment column: 'Sentiment') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              412      185       116
# DAP              68       47        29
# GPS               5        6         1
# GRS               2        6         1
# GTA              74       70        35
# PAS              33       17         9
# PH              178       91        53
# PKR              39       14         4
# PN              164       99        28
# UMNO            327      137       133
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      59
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PKR                    39             14               4        0.684211
# BN                    412            185             116        0.577840
# PN                    164             99              28        0.563574
# PAS                    33             17               9        0.559322
# PH                    178             91              53        0.552795
# UMNO                  327            137             133        0.547739
# DAP                    68             47              29        0.472222
# GPS                     5              6               1        0.416667
# GTA                    74             70              35        0.413408
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PKR             0.245614        0.070175          9.750000
# BN              0.259467        0.162693          3.551724
# PN              0.340206        0.096220          5.857143
# PAS             0.288136        0.152542          3.666667
# PH              0.282609        0.164596          3.358491
# UMNO            0.229481        0.222781          2.458647
# DAP             0.326389        0.201389          2.344828
# GPS             0.500000        0.083333          5.000000
# GTA             0.391061        0.195531          2.114286
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PKR              0.684211
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# GTA              0.413408
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing combined_textblob.csv (sentiment column: 'predicted_label') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              297      367        49
# DAP              43       79        22
# GPS               5        7         0
# GRS               4        5         0
# GTA              51      104        24
# PAS              22       28         9
# PH              134      162        26
# PKR              20       32         5
# PN              138      140        13
# UMNO            274      285        38
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      59
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PN                    138            140              13        0.474227
# UMNO                  274            285              38        0.458961
# GPS                     5              7               0        0.416667
# BN                    297            367              49        0.416550
# PH                    134            162              26        0.416149
# PAS                    22             28               9        0.372881
# PKR                    20             32               5        0.350877
# DAP                    43             79              22        0.298611
# GTA                    51            104              24        0.284916
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PN              0.481100        0.044674         10.615385
# UMNO            0.477387        0.063652          7.210526
# GPS             0.583333        0.000000               inf
# BN              0.514727        0.068724          6.061224
# PH              0.503106        0.080745          5.153846
# PAS             0.474576        0.152542          2.444444
# PKR             0.561404        0.087719          4.000000
# DAP             0.548611        0.152778          1.954545
# GTA             0.581006        0.134078          2.125000
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PN               0.474227
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# GTA              0.284916
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing combined_vader.csv (sentiment column: 'predicted_label') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              416      181       116
# DAP              69       46        29
# GPS               5        6         1
# GRS               2        6         1
# GTA              74       70        35
# PAS              34       16         9
# PH              181       89        52
# PKR              39       14         4
# PN              168       95        28
# UMNO            329      136       132
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      59
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PKR                    39             14               4        0.684211
# BN                    416            181             116        0.583450
# PN                    168             95              28        0.577320
# PAS                    34             16               9        0.576271
# PH                    181             89              52        0.562112
# UMNO                  329            136             132        0.551089
# DAP                    69             46              29        0.479167
# GPS                     5              6               1        0.416667
# GTA                    74             70              35        0.413408
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PKR             0.245614        0.070175          9.750000
# BN              0.253857        0.162693          3.586207
# PN              0.326460        0.096220          6.000000
# PAS             0.271186        0.152542          3.777778
# PH              0.276398        0.161491          3.480769
# UMNO            0.227806        0.221106          2.492424
# DAP             0.319444        0.201389          2.379310
# GPS             0.500000        0.083333          5.000000
# GTA             0.391061        0.195531          2.114286
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PKR              0.684211
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# GTA              0.413408
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing dataset_chatgpt_sentiment.csv (sentiment column: 'Sentiment') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              335      304        74
# DAP              49       56        39
# GPS               5        7         0
# GRS               5        4         0
# GTA              61       90        28
# PAS              26       18        15
# PH              145      138        39
# PKR              25       27         5
# PN              148      124        19
# UMNO            299      240        58
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      59
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PN                    148            124              19        0.508591
# UMNO                  299            240              58        0.500838
# BN                    335            304              74        0.469846
# PH                    145            138              39        0.450311
# PAS                    26             18              15        0.440678
# PKR                    25             27               5        0.438596
# GPS                     5              7               0        0.416667
# GTA                    61             90              28        0.340782
# DAP                    49             56              39        0.340278
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PN              0.426117        0.065292          7.789474
# UMNO            0.402010        0.097152          5.155172
# BN              0.426367        0.103787          4.527027
# PH              0.428571        0.121118          3.717949
# PAS             0.305085        0.254237          1.733333
# PKR             0.473684        0.087719          5.000000
# GPS             0.583333        0.000000               inf
# GTA             0.502793        0.156425          2.178571
# DAP             0.388889        0.270833          1.256410
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PN               0.508591
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# DAP              0.340278
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing bert_predictions_all(TextBlob).csv (sentiment column: 'BERT_Predicted_Sentiment') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              295      359        59
# DAP              42       80        22
# GPS               5        7         0
# GRS               5        4         0
# GTA              54      103        22
# PAS              26       30         3
# PH              129      165        28
# PKR              20       34         3
# PN              135      144        12
# UMNO            275      283        39
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      59
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PN                    135            144              12        0.463918
# UMNO                  275            283              39        0.460637
# PAS                    26             30               3        0.440678
# GPS                     5              7               0        0.416667
# BN                    295            359              59        0.413745
# PH                    129            165              28        0.400621
# PKR                    20             34               3        0.350877
# GTA                    54            103              22        0.301676
# DAP                    42             80              22        0.291667
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PN              0.494845        0.041237         11.250000
# UMNO            0.474037        0.065327          7.051282
# PAS             0.508475        0.050847          8.666667
# GPS             0.583333        0.000000               inf
# BN              0.503506        0.082749          5.000000
# PH              0.512422        0.086957          4.607143
# PKR             0.596491        0.052632          6.666667
# GTA             0.575419        0.122905          2.454545
# DAP             0.555556        0.152778          1.909091
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PN               0.463918
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# DAP              0.291667
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing bert_predictions_all(VADER).csv (sentiment column: 'BERT_Predicted_Sentiment') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              391      176       146
# DAP              68       43        33
# GPS               5        6         1
# GRS               2        6         1
# GTA              72       66        41
# PAS              34       17         8
# PH              174       86        62
# PKR              38       14         5
# PN              158       98        35
# UMNO            310      129       158
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      59
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PKR                    38             14               5        0.666667
# PAS                    34             17               8        0.576271
# BN                    391            176             146        0.548387
# PN                    158             98              35        0.542955
# PH                    174             86              62        0.540373
# UMNO                  310            129             158        0.519263
# DAP                    68             43              33        0.472222
# GPS                     5              6               1        0.416667
# GTA                    72             66              41        0.402235
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PKR             0.245614        0.087719          7.600000
# PAS             0.288136        0.135593          4.250000
# BN              0.246844        0.204769          2.678082
# PN              0.336770        0.120275          4.514286
# PH              0.267081        0.192547          2.806452
# UMNO            0.216080        0.264657          1.962025
# DAP             0.298611        0.229167          2.060606
# GPS             0.500000        0.083333          5.000000
# GTA             0.368715        0.229050          1.756098
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PKR              0.666667
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# GTA              0.402235
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# --- Analyzing bert_predictions_all(ChatGpt).csv (sentiment column: 'BERT_Predicted_Sentiment') ---
#
# Party-wise sentiment counts:
#  Sentiment  Positive  Neutral  Negative
# Party
# BN              339      301        73
# DAP              48       57        39
# GPS               5        7         0
# GRS               5        4         0
# GTA              59       92        28
# PAS              27       19        13
# PH              145      140        37
# PKR              26       27         4
# PN              148      124        19
# UMNO            303      237        57
# Top 10 most frequently mentioned parties:
#  Party
# BN      713
# UMNO    597
# PH      322
# PN      291
# GTA     179
# DAP     144
# PAS      59
# PKR      57
# GPS      12
# GRS       9
# Name: count, dtype: int64
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:158: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Party sentiment ratios (only parties with ≥10 total mentions):
#  Sentiment  Positive_Count  Neutral_Count  Negative_Count  Positive_Ratio  \
# Party
# PN                    148            124              19        0.508591
# UMNO                  303            237              57        0.507538
# BN                    339            301              73        0.475456
# PAS                    27             19              13        0.457627
# PKR                    26             27               4        0.456140
# PH                    145            140              37        0.450311
# GPS                     5              7               0        0.416667
# DAP                    48             57              39        0.333333
# GTA                    59             92              28        0.329609
#
# Sentiment  Neutral_Ratio  Negative_Ratio  Pos_vs_Neg_Ratio
# Party
# PN              0.426117        0.065292          7.789474
# UMNO            0.396985        0.095477          5.315789
# BN              0.422160        0.102384          4.643836
# PAS             0.322034        0.220339          2.076923
# PKR             0.473684        0.070175          6.500000
# PH              0.434783        0.114907          3.918919
# GPS             0.583333        0.000000               inf
# DAP             0.395833        0.270833          1.230769
# GTA             0.513966        0.156425          2.107143
#
# Most Favorable Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# PN               0.508591
# Most Critical Party (≥10 mentions):
#  Sentiment  Positive_Ratio
# Party
# GTA              0.329609
# C:\Users\amirb\AppData\Local\Temp\ipykernel_16840\1880487658.py:250: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
